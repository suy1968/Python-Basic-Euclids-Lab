# %% [markdown]
# ![circle-Logo%20Small.png](attachment:circle-Logo%20Small.png)

# %% [markdown]
# # Pandas
#
# Pandas is an open-source Python Library. We use it for data manipulation and analysis.
# Using Pandas we can perform following functions
#
# 1. Load and read data objects from different file formats.
# 2. Label-based slicing, indexing and subsetting of large data sets.
# 3. Delete or insert Columns in a dataframe.
# 4. Create custom dataframe and series.
# 5. Group by data for aggregation and transformations.
# 6. Merging and joining of data.

# %% [markdown]
# **Import Pandas and Numpy Library**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Pandas deals with the three types data structures**
#
# 1. Series: It is a 1D labeled homogeneous array, sizeimmutable.
# 2. DataFrame: It is a 2D labeled, size-mutable tabular structure with potentially heterogeneously typed columns.
# 3. Panel: General 3D labeled, size-mutable array.

# %% [markdown]
# ### Series
#
# Series is a one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects, etc.). The axis labels are collectively called index.
#
# A Series is very similar to a NumPy array. It is built on top of the NumPy array object).
#
# A series can be created using various inputs like −
# 1. Array
# 2. Dict
# 3. Scalar value or constant

# %%
#Create a Series from 1-D array of 'A','B','C','D'
arr = np.array(['A','B','C','D'])
pd.Series(data= arr)
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# dtype: object

# %%
#Change index of the above array form 0,1,2,3 with 100,101,102,103
index = np.array([100,101,102,103])
pd.Series(data=arr, index=index)
# Out:
# 100    A
# 101    B
# 102    C
# 103    D
# dtype: object

# %% [markdown]
# ### Dataframe
#
# A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.
#
# 1. Labelled axes for row and columns.
# 2. Arthematic operations on row and columns.
# 3. It is size mutable.
#
# **pandas.DataFrame( data, index, columns, dtype, copy)**

# %%
#Create a Dataframe from 1-D array of 'A','B','C','D'
#Name column as Alphabets
data = np.array('A B C D'.split())
pd.DataFrame(data=data,columns=['Alphabets'])
# Out:
#   Alphabets
# 0         A
# 1         B
# 2         C
# 3         D

# %% [markdown]
# **Read File**
#
# We can also create a DataFrame by importing a CSV file. A CSV file is a text file with one record of data per line. The values within the record are separated using the “comma” character.
#
# Pandas provides a useful method, named read_csv() to read the contents of the CSV file into a DataFrame.
#
# We are downloading the BostonHousing dataset file from Kaggle
#
# * CRIM - per capita crime rate by town
# * ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# * INDUS - proportion of non-retail business acres per town.
# * CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# * NOX - nitric oxides concentration (parts per 10 million)
# * RM - average number of rooms per dwelling
# * AGE - proportion of owner-occupied units built prior to 1940
# * DIS - weighted distances to five Boston employment centres
# * RAD - index of accessibility to radial highways
# * TAX - full-value property-tax rate per 10,000 dollers
# * PTRATIO - pupil-teacher ratio by town
# * B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# * LSTAT - % lower status of the population
# * MEDV - Median value of owner-occupied homes in $1000's

# %%
#Read CSV file using pandas read_csv()
fileName= 'BostonHousing.csv'
df = pd.read_csv(fileName)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# ### Inspecting Dataframe
#
# 1. head()
# 2. tail()
# 3. shape
# 4. info()
# 5. describe()

# %% [markdown]
# **head()**
#
# Return first n rows. By default it gives first 5 rows

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %% [markdown]
# **tail()**
#
# Return last n rows. By default it gives last 5 rows

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 501  391.99    NaN  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %% [markdown]
# **shape**

# %%
df.shape
# Out:
# (506, 14)

# %% [markdown]
# **info()**
#
# It is used to get a concise summary of the dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       486 non-null float64
# ZN         486 non-null float64
# INDUS      486 non-null float64
# CHAS       486 non-null float64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        486 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null int64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      486 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %% [markdown]
# **describe()**
#
# It is used to view some basic statistical details like percentile, mean, std etc.

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560262   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# **Data Slicing**

# %% [markdown]
# **Slice Single column**

# %%
#Check CRIM column of the dataframe
df['CRIM']
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64

# %%
df.CRIM
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64

# %% [markdown]
# **Slicing Multiple Coulmns**

# %%
#Check CRIM and TAX column of the dataframe
df[['CRIM','TAX']]
# Out:
#         CRIM  TAX
# 0    0.00632  296
# 1    0.02731  242
# 2    0.02729  242
# 3    0.03237  222
# 4    0.06905  222
# ..       ...  ...
# 501  0.06263  273
# 502  0.04527  273
# 503  0.06076  273
# 504  0.10959  273
# 505  0.04741  273
#
# [506 rows x 2 columns]

# %% [markdown]
# **Slicing Row**

# %%
#Get/Slice rows 0 to 2 from the dataframe
df.loc[0:2]
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7

# %%
#Get all the values from row 2. We use iloc when we deal with row values.
df.iloc[2,:]
# Out:
# CRIM         0.02729
# ZN           0.00000
# INDUS        7.07000
# CHAS         0.00000
# NOX          0.46900
# RM           7.18500
# AGE         61.10000
# DIS          4.96710
# RAD          2.00000
# TAX        242.00000
# PTRATIO     17.80000
# B          392.83000
# LSTAT        4.03000
# MEDV        34.70000
# Name: 2, dtype: float64

# %% [markdown]
# **Filtering Data**

# %%
#Filter dataframe for all the houses with Age less than 40. 
#Here condition is that "df.AGE < 40"
df[df['AGE']<40].head()
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 12  0.09378  12.5   7.87   0.0  0.524  5.889  39.0  5.4509    5  311     15.2
# 16  1.05393   0.0   8.14   0.0  0.538  5.935  29.3  4.4986    4  307     21.0
# 18  0.80271   0.0   8.14   0.0  0.538  5.456  36.6  3.7965    4  307     21.0
# 38  0.17505   0.0   5.96   0.0  0.499  5.966  30.2  3.8473    5  279     19.2
# 39  0.02763  75.0   2.95   0.0  0.428  6.595  21.8  5.4011    3  252     18.3
#
#          B  LSTAT  MEDV
# 12  390.50  15.71  21.7
# 16  386.85   6.58  23.1
# 18  288.99  11.69  20.2
# 38  393.43  10.13  24.7
# 39  395.63   4.32  30.8

# %% [markdown]
# **Sort Values**

# %%
#Sort whole dataframe w.r.t. MEDV values, either ascending or descending order. 
df.sort_values('MEDV',ascending=True)
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 398  38.35180   0.0  18.10   0.0  0.693  5.453  100.0  1.4896   24  666
# 405  67.92080   0.0  18.10   0.0  0.693  5.683  100.0  1.4254   24  666
# 400  25.04610   0.0  18.10   0.0  0.693  5.987  100.0  1.5888   24  666
# 399   9.91655   0.0  18.10   0.0  0.693  5.852   77.8  1.5004   24  666
# 414  45.74610   0.0  18.10   0.0  0.693  4.519  100.0  1.6582   24  666
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 166   2.01019   0.0  19.58   0.0  0.605  7.929   96.2  2.0459    5  403
# 195   0.01381  80.0   0.46   0.0  0.422  7.875   32.0  5.6484    4  255
# 283   0.01501  90.0   1.21   1.0  0.401  7.923   24.8  5.8850    1  198
# 225   0.52693   0.0   6.20   0.0  0.504  8.725   83.0  2.8944    8  307
# 186   0.05602   NaN   2.46   0.0  0.488  7.831   53.6  3.1992    3  193
#
#      PTRATIO       B  LSTAT  MEDV
# 398     20.2  396.90  30.59   5.0
# ...

# %% [markdown]
# ### Statistics
#
# 1. count()
# 2. sum()
# 3. mean(), median(), std()
# 4. min(), max()

# %%
#Get the sum of all values from CRIM
df.CRIM.sum()
# Out:
# 1755.37075

# %%
#Get the min value of CRIM.
df.CRIM.min()
# Out:
# 0.00632

# %% [markdown]
# **In a similar way you can find out rest of the statistical values**

# %% [markdown]
# ### Iteration

# %% [markdown]
# **iteritems()**
#
# Iterates over each column as key, value pair with label as key and column value as a Series object.

# %%
#Use for loop to iterate over the CRIM column. You will get key(index) and value from CRIM column
for key,value in df.CRIM.iteritems():
     if key == 0:
        print('key:',key ,'\t', 'value:',value)
# Out:
# key: 0 	 value: 0.00632

# %% [markdown]
# **iterrows()**
#
# iterrows() returns the iterator yielding each index value along with a series containing the data in each row.

# %%
#Use for loop to iterate over the Rows. You will get key(index) and value from all the column for that row
for row_index,column in df.iterrows():
    if row_index == 0:
        print(row_index,column)
# Out:
# 0 CRIM         0.00632
# ZN          18.00000
# INDUS        2.31000
# CHAS         0.00000
# NOX          0.53800
# RM           6.57500
# AGE         65.20000
# DIS          4.09000
# RAD          1.00000
# TAX        296.00000
# PTRATIO     15.30000
# B          396.90000
# LSTAT        4.98000
# MEDV        24.00000
# Name: 0, dtype: float64

# %% [markdown]
# ### groupby()
#
# Groupby operations are performed by:
# 1. Spliting the object
# 2. Applying a function
# 3. Combining the result

# %%
#Group the dataframe w.r.t 'CHAS' using groupby()
df.groupby('CHAS')

# %% [markdown]
# ### Concatination
#
# The concat() used for concatenation operations along an axis. Let us create different objects and do concatenation.

# %%
science = pd.DataFrame({
   'Institure': ['IITK', 'DU', 'IITM','IISc','IITB'],
   'Rank_scored':[92,90,87,97,88]},
   index=[1,2,3,4,5])

mba = pd.DataFrame({
   'Institure': ['TISS', 'IIMA', 'XLRI','FMS','ISB'],
   'Rank_scored':[98,95,87,97,88]},
   index=[1,2,3,4,5])

# %%
#Concatinate science and mba dataframe along axis 0
pd.concat([science,mba])
# Out:
#   Institure  Rank_scored
# 1      IITK           92
# 2        DU           90
# 3      IITM           87
# 4      IISc           97
# 5      IITB           88
# 1      TISS           98
# 2      IIMA           95
# 3      XLRI           87
# 4       FMS           97
# 5       ISB           88

# %%
#Concatinate science and mba dataframe along axis 0. Use keys 'Science' and 'MBA'
pd.concat([science,mba],keys=['Science','Mba'])
# Out:
#           Institure  Rank_scored
# Science 1      IITK           92
#         2        DU           90
#         3      IITM           87
#         4      IISc           97
#         5      IITB           88
# Mba     1      TISS           98
#         2      IIMA           95
#         3      XLRI           87
#         4       FMS           97
#         5       ISB           88

# %%
#Concatinate science and mba dataframe along axis 1
pd.concat([science,mba],axis=1)
# Out:
#   Institure  Rank_scored Institure  Rank_scored
# 1      IITK           92      TISS           98
# 2        DU           90      IIMA           95
# 3      IITM           87      XLRI           87
# 4      IISc           97       FMS           97
# 5      IITB           88       ISB           88

# %%
#Concatinate science and mba dataframe along axis 1. Use keys 'Science' and 'MBA'
pd.concat([science,mba],axis=1, keys=['Science','Mba'])
# Out:
#     Science                   Mba
#   Institure Rank_scored Institure Rank_scored
# 1      IITK          92      TISS          98
# 2        DU          90      IIMA          95
# 3      IITM          87      XLRI          87
# 4      IISc          97       FMS          97
# 5      IITB          88       ISB          88

# %% [markdown]
# ### Visualization
#
# It gives us the basic Plot function. Its a wrapper around the matplot library.
#
# plot()

# %% [markdown]
# **Histogram plot**

# %% [markdown]
# Take BostonHousing dataframe using df=pd.read_csv('BostonHousing.csv',usecols=['AGE'])
# Plot histogram form bin size of 30.

# %%
#Create histogram plot for the following dataframe
df=pd.read_csv('BostonHousing.csv',usecols=['AGE','TAX'])
df.AGE.plot.hist(bins=30)

# %% [markdown]
# **Scatter Plot**
# Take BostonHousing dataframe using df=pd.read_csv('BostonHousing.csv',usecols=['AGE','TAX'])
# Plot scatter plot

# %%
#Draw a scatter plot between 'AGE' and 'TAX'
df.plot.scatter(x='AGE',y='TAX')
